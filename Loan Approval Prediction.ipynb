# %% [markdown]
# # Data Science Project  (Assignment)
#
# ## Phase 1: Problem Understanding (5 Marks)

# %% [markdown]
# ## Business Problem
#
# Financial institutions receive a large number of loan applications every day. Evaluating each application manually can be time-consuming and may lead to inconsistent decisions. Approving loans for applicants who are unable to repay increases financial risk, while rejecting eligible applicants may result in lost business opportunities.
#
# This project aims to analyze applicant information and build a Machine Learning model that predicts whether a loan application should be approved or rejected. The prediction will help financial institutions make faster, more accurate, and data-driven loan approval decisions.

# %% [markdown]
# ## 2. Identify the target variable:

# %% [markdown]
# ## Target Variable
#
# The target variable in this dataset is **loan_status**.
#
# It represents the final decision on a loan application.
#
# Possible values:
# - Approved
# - Rejected
#
# The Machine Learning model will learn from the input features to predict the value of the target variable.

# %% [markdown]
# ##	Decide whether it is: :

# %% [markdown]
# ## Problem Type
#
# This project is a **Supervised Machine Learning - Classification** problem.
#
# Reason:
# - The target variable (loan_status) contains categorical values.
# - The model predicts one of two classes:
#     - Approved
#     - Rejected
#
# Therefore, Classification is the appropriate Machine Learning technique.
#
# Regression is not suitable because the target variable is not continuous.
#
# Clustering is not suitable because the dataset already contains a target variable.

# %% [markdown]
# Deliverables
# ## Problem Statement
#
# Develop a Machine Learning model that predicts whether a loan application should be approved or rejected based on the applicant's financial and personal information.

# %% [markdown]
# ## Business Objective
#
# The objective of this project is to assist financial institutions in making faster and more accurate loan approval decisions.
#
# The project aims to:
# - Reduce the risk of loan defaults.
# - Improve decision-making.
# - Automate the loan approval process.
# - Save time and operational costs.

# %% [markdown]
# ## Success Criteria
#
# The project will be considered successful if:
#
# - The dataset is cleaned and preprocessed successfully.
# - Exploratory Data Analysis (EDA) provides meaningful insights.
# - A Machine Learning classification model is developed.
# - The model achieves good performance using evaluation metrics such as Accuracy, Precision, Recall, and F1-Score.

# %% [markdown]
# # Phase 2: Dataset Understanding
#
# ## Dataset Overview
#
# The dataset contains applicant information such as income, education, loan amount, credit score, and asset values. These features are used to predict whether a loan application will be approved or rejected.
#
# The dataset contains both numerical and categorical variables.

# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings(action='ignore')

# %%
df=pd.read_csv(r"C:\Users\USER\Downloads\loan_approval_dataset.csv.xls")

# %%
df.head()
# Out:
#    loan_id  no_of_dependents      education  self_employed   income_annum  \
# 0        1                 2       Graduate             No        9600000
# 1        2                 0   Not Graduate            Yes        4100000
# 2        3                 3       Graduate             No        9100000
# 3        4                 3       Graduate             No        8200000
# 4        5                 5   Not Graduate            Yes        9800000
#
#     loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0      29900000          12           778                    2400000
# 1      12200000           8           417                    2700000
# 2      29700000          20           506                    7100000
# 3      30700000           8           467                   18200000
# 4      24200000          20           382                   12400000
#
#     commercial_assets_value   luxury_assets_value   bank_asset_value  \
# 0                  17600000              22700000            8000000
# 1                   2200000               8800000            3300000
# 2                   4500000              33300000           12800000
# 3                   3300000              23300000            7900000
# 4                   8200000              29400000            5000000
#
#    loan_status
# 0     Approved
# 1     Rejected
# 2     Rejected
# 3     Rejected
# 4     Rejected

# %%
df.shape
# Out:
# (4269, 13)

# %%
df.dtypes
# Out:
# loan_id                       int64
# no_of_dependents              int64
#  education                   object
#  self_employed               object
#  income_annum                 int64
#  loan_amount                  int64
#  loan_term                    int64
#  cibil_score                  int64
#  residential_assets_value     int64
#  commercial_assets_value      int64
#  luxury_assets_value          int64
#  bank_asset_value             int64
#  loan_status                 object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   loan_id                    4269 non-null   int64
#  1   no_of_dependents           4269 non-null   int64
#  2    education                 4269 non-null   object
#  3    self_employed             4269 non-null   object
#  4    income_annum              4269 non-null   int64
#  5    loan_amount               4269 non-null   int64
#  6    loan_term                 4269 non-null   int64
#  7    cibil_score               4269 non-null   int64
#  8    residential_assets_value  4269 non-null   int64
#  9    commercial_assets_value   4269 non-null   int64
#  10   luxury_assets_value       4269 non-null   int64
#  11   bank_asset_value          4269 non-null   int64
#  12   loan_status               4269 non-null   object
# dtypes: int64(10), object(3)
# memory usage: 433.7+ KB

# %% [markdown]
# ## Feature Description
#
# | Feature | Description |
# |---------|-------------|
# | loan_id | Unique loan application ID |
# | no_of_dependents | Number of dependents |
# | education | Applicant's education level |
# | self_employed | Employment status |
# | income_annum | Annual income |
# | loan_amount | Requested loan amount |
# | loan_term | Loan repayment period |
# | cibil_score | Applicant's credit score |
# | residential_assets_value | Residential property value |
# | commercial_assets_value | Commercial property value |
# | luxury_assets_value | Luxury asset value |
# | bank_asset_value | Bank asset value |
# | loan_status | Loan approval status (Target Variable) |

# %% [markdown]
# ## Target Variable Description
#
# Target Variable: loan_status
#
# Description:
# This variable indicates whether the loan application is Approved or Rejected.
#
# Machine Learning Type:
# Binary Classification

# %% [markdown]
# ## Deliverables
# ### Dataset summary

# %%
print (df.shape)

print (df.columns)

print (df.dtypes)
# Out:
# (4269, 13)
# Index(['loan_id', 'no_of_dependents', ' education', ' self_employed',
#        ' income_annum', ' loan_amount', ' loan_term', ' cibil_score',
#        ' residential_assets_value', ' commercial_assets_value',
#        ' luxury_assets_value', ' bank_asset_value', ' loan_status'],
#       dtype='object')
# loan_id                       int64
# no_of_dependents              int64
#  education                   object
#  self_employed               object
#  income_annum                 int64
#  loan_amount                  int64
#  loan_term                    int64
#  cibil_score                  int64
#  residential_assets_value     int64
#  commercial_assets_value      int64
#  luxury_assets_value          int64
#  bank_asset_value             int64
#  loan_status                 object
# dtype: object

# %% [markdown]
# ##	Data dictionary

# %%
data_dictionary = pd.DataFrame({
    "Column Name": df.columns,
    "Data Type": df.dtypes.values
})

data_dictionary
# Out:
#                   Column Name Data Type
# 0                     loan_id     int64
# 1            no_of_dependents     int64
# 2                   education    object
# 3               self_employed    object
# 4                income_annum     int64
# 5                 loan_amount     int64
# 6                   loan_term     int64
# 7                 cibil_score     int64
# 8    residential_assets_value     int64
# 9     commercial_assets_value     int64
# 10        luxury_assets_value     int64
# 11           bank_asset_value     int64
# 12                loan_status    object

# %% [markdown]
# Phase 3: Data Collection & Loading (5 Marks)

# %%
data_dictionary = pd.DataFrame({
    "Column Name": df.columns,
    "Data Type": df.dtypes.values
})

data_dictionary
# Out:
#                   Column Name Data Type
# 0                     loan_id     int64
# 1            no_of_dependents     int64
# 2                   education    object
# 3               self_employed    object
# 4                income_annum     int64
# 5                 loan_amount     int64
# 6                   loan_term     int64
# 7                 cibil_score     int64
# 8    residential_assets_value     int64
# 9     commercial_assets_value     int64
# 10        luxury_assets_value     int64
# 11           bank_asset_value     int64
# 12                loan_status    object

# %% [markdown]
# # Phase 3: Data Collection & Loading (5 Marks)

# %% [markdown]
# # Phase 3: Data Collection & Loading
# This phase involves importing the required libraries, loading the dataset, and understanding its basic structure.

# %% [markdown]
# ## import required libraries

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# ## load dataset

# %%
df=pd.read_csv(r"C:\Users\USER\Desktop\All Data sets in python\loan_approval_dataset_classification.csv")

# %%
# 	Display first 5` records
df.head()
# Out:
#    loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0        1                  2       Graduate             No        9600000
# 1        2                  0   Not Graduate            Yes        4100000
# 2        3                  3       Graduate             No        9100000
# 3        4                  3       Graduate             No        8200000
# 4        5                  5   Not Graduate            Yes        9800000
#
#     loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0      29900000          12           778                    2400000
# 1      12200000           8           417                    2700000
# 2      29700000          20           506                    7100000
# 3      30700000           8           467                   18200000
# 4      24200000          20           382                   12400000
#
#     commercial_assets_value   luxury_assets_value   bank_asset_value  \
# 0                  17600000              22700000            8000000
# 1                   2200000               8800000            3300000
# 2                   4500000              33300000           12800000
# 3                   3300000              23300000            7900000
# 4                   8200000              29400000            5000000
#
#    loan_status
# 0     Approved
# 1     Rejected
# 2     Rejected
# 3     Rejected
# 4     Rejected

# %%
# last records 

df.tail()
# Out:
#       loan_id   no_of_dependents      education  self_employed   income_annum  \
# 4264     4265                  5       Graduate            Yes        1000000
# 4265     4266                  0   Not Graduate            Yes        3300000
# 4266     4267                  2   Not Graduate             No        6500000
# 4267     4268                  1   Not Graduate             No        4100000
# 4268     4269                  1       Graduate             No        9200000
#
#        loan_amount   loan_term   cibil_score   residential_assets_value  \
# 4264       2300000          12           317                    2800000
# 4265      11300000          20           559                    4200000
# 4266      23900000          18           457                    1200000
# 4267      12800000           8           780                    8200000
# 4268      29700000          10           607                   17800000
#
#        commercial_assets_value   luxury_assets_value   bank_asset_value  \
# 4264                    500000               3300000             800000
# 4265                   2900000              11000000            1900000
# 4266                  12400000              18100000            7300000
# 4267                    700000              14100000            5800000
# 4268                  11800000              35700000           12000000
#
#       loan_status
# 4264     Rejected
# 4265     Approved
# 4266     Rejected
# 4267     Approved
# 4268     Approved

# %%
df.shape
# Out:
# (4269, 13)

# %%
df.dtypes
# Out:
# loan_id                       int64
#  no_of_dependents             int64
#  education                   object
#  self_employed               object
#  income_annum                 int64
#  loan_amount                  int64
#  loan_term                    int64
#  cibil_score                  int64
#  residential_assets_value     int64
#  commercial_assets_value      int64
#  luxury_assets_value          int64
#  bank_asset_value             int64
#  loan_status                 object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   loan_id                    4269 non-null   int64
#  1    no_of_dependents          4269 non-null   int64
#  2    education                 4269 non-null   object
#  3    self_employed             4269 non-null   object
#  4    income_annum              4269 non-null   int64
#  5    loan_amount               4269 non-null   int64
#  6    loan_term                 4269 non-null   int64
#  7    cibil_score               4269 non-null   int64
#  8    residential_assets_value  4269 non-null   int64
#  9    commercial_assets_value   4269 non-null   int64
#  10   luxury_assets_value       4269 non-null   int64
#  11   bank_asset_value          4269 non-null   int64
#  12   loan_status               4269 non-null   object
# dtypes: int64(10), object(3)
# memory usage: 433.7+ KB

# %% [markdown]
# # Phase 4: Data Cleaning (15 Marks)

# %% [markdown]
# ##	Missing values

# %%
df.isnull().sum()
# Out:
# loan_id                      0
#  no_of_dependents            0
#  education                   0
#  self_employed               0
#  income_annum                0
#  loan_amount                 0
#  loan_term                   0
#  cibil_score                 0
#  residential_assets_value    0
#  commercial_assets_value     0
#  luxury_assets_value         0
#  bank_asset_value            0
#  loan_status                 0
# dtype: int64

# %%
df.fillna(method='ffill',inplace=True)

# %%
df.dropna(inplace=True)

# %% [markdown]
# ## Duplicate records

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# ##	Incorrect data types

# %%
df.dtypes
# Out:
# loan_id                       int64
#  no_of_dependents             int64
#  education                   object
#  self_employed               object
#  income_annum                 int64
#  loan_amount                  int64
#  loan_term                    int64
#  cibil_score                  int64
#  residential_assets_value     int64
#  commercial_assets_value      int64
#  luxury_assets_value          int64
#  bank_asset_value             int64
#  loan_status                 object
# dtype: object

# %%
df.columns.tolist()
# Out:
# ['loan_id',
#  ' no_of_dependents',
#  ' education',
#  ' self_employed',
#  ' income_annum',
#  ' loan_amount',
#  ' loan_term',
#  ' cibil_score',
#  ' residential_assets_value',
#  ' commercial_assets_value',
#  ' luxury_assets_value',
#  ' bank_asset_value',
#  ' loan_status']

# %%
for col in df.columns:
    print(repr(col))
# Out:
# 'loan_id'
# ' no_of_dependents'
# ' education'
# ' self_employed'
# ' income_annum'
# ' loan_amount'
# ' loan_term'
# ' cibil_score'
# ' residential_assets_value'
# ' commercial_assets_value'
# ' luxury_assets_value'
# ' bank_asset_value'
# ' loan_status'

# %%
df.columns = df.columns.str.strip()

# %%
df.rename(columns={'loan_term':'loan_term_years','bank_asset_value':'bank_balance'},inplace=True)

# %%
df.head(2)
# Out:
#    loan_id  no_of_dependents      education self_employed  income_annum  \
# 0        1                 2       Graduate            No       9600000
# 1        2                 0   Not Graduate           Yes       4100000
#
#    loan_amount  loan_term_years  cibil_score  residential_assets_value  \
# 0     29900000               12          778                   2400000
# 1     12200000                8          417                   2700000
#
#    commercial_assets_value  luxury_assets_value  bank_balance loan_status
# 0                 17600000             22700000       8000000    Approved
# 1                  2200000              8800000       3300000    Rejected

# %%
df.rename(columns={' income_annum': 'income_year'},inplace=True)

# %%
df.head(2)
# Out:
#    loan_id  no_of_dependents      education self_employed  income_annum  \
# 0        1                 2       Graduate            No       9600000
# 1        2                 0   Not Graduate           Yes       4100000
#
#    loan_amount  loan_term_years  cibil_score  residential_assets_value  \
# 0     29900000               12          778                   2400000
# 1     12200000                8          417                   2700000
#
#    commercial_assets_value  luxury_assets_value  bank_balance loan_status
# 0                 17600000             22700000       8000000    Approved
# 1                  2200000              8800000       3300000    Rejected

# %% [markdown]
# ## 	Outlier detection

# %%
sns.boxplot(data=df['income_annum'])
plt.show()

# %%
df.head(2)
# Out:
#    loan_id  no_of_dependents      education self_employed  income_annum  \
# 0        1                 2       Graduate            No       9600000
# 1        2                 0   Not Graduate           Yes       4100000
#
#    loan_amount  loan_term_years  cibil_score  residential_assets_value  \
# 0     29900000               12          778                   2400000
# 1     12200000                8          417                   2700000
#
#    commercial_assets_value  luxury_assets_value  bank_balance loan_status
# 0                 17600000             22700000       8000000    Approved
# 1                  2200000              8800000       3300000    Rejected

# %% [markdown]
# ## Inconsistent values

# %%
df.replace({'graduate':'Degree','approved':'Confirmed'},inplace=True)

# %%
df.head(3)
# Out:
#    loan_id  no_of_dependents      education self_employed  income_annum  \
# 0        1                 2       Graduate            No       9600000
# 1        2                 0   Not Graduate           Yes       4100000
# 2        3                 3       Graduate            No       9100000
#
#    loan_amount  loan_term_years  cibil_score  residential_assets_value  \
# 0     29900000               12          778                   2400000
# 1     12200000                8          417                   2700000
# 2     29700000               20          506                   7100000
#
#    commercial_assets_value  luxury_assets_value  bank_balance loan_status
# 0                 17600000             22700000       8000000    Approved
# 1                  2200000              8800000       3300000    Rejected
# 2                  4500000             33300000      12800000    Rejected

# %%
 df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# loan_id                      int64
# no_of_dependents             int64
# education                   object
# self_employed               object
# income_annum                 int64
# loan_amount                  int64
# loan_term_years              int64
# cibil_score                  int64
# residential_assets_value     int64
# commercial_assets_value      int64
# luxury_assets_value          int64
# bank_balance                 int64
# loan_status                 object
# dtype: object

# %%
 df.isnull().sum()
# Out:
# loan_id                     0
# no_of_dependents            0
# education                   0
# self_employed               0
# income_annum                0
# loan_amount                 0
# loan_term_years             0
# cibil_score                 0
# residential_assets_value    0
# commercial_assets_value     0
# luxury_assets_value         0
# bank_balance                0
# loan_status                 0
# dtype: int64

# %% [markdown]
# # Phase 5: Exploratory Data Analysis (EDA) (20 Marks)
#
# # Univariate Analysis

# %% [markdown]
# ## 	Histogram

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['income_annum'],bins=56, kde=True)
plt.title("Income Distribution")
plt.xlabel('Income per Annum')
plt.ylabel('Frequence')
plt.show()

# %% [markdown]
# Insights:
# * Income per Annum similarly spreaded across the dataset
# * but some people have more annual income compare to others
# * because income per annum impact a lot for loan approval
# * the histrogram does not show any major gaps,meanings applicants are distributed throughout the income range.
# * income values are widely distributed
# * Applicants from low, middle,and hight income groups are represented in the dataset.

# %% [markdown]
# ## 	Count Plot

# %%
sns.countplot(x='loan_status', data=df)
plt.title('loan_status')
plt.show()

# %% [markdown]
# insights:
#
# - the dataset contains more approvel loans than rejected loans
# - most of the loan applicants  are approved around 2650
# - most of the loan applicants are rejected around 1600
# - majority of applicants meet the eligibility criteria for loan approval.

# %% [markdown]
# ## Box Plot

# %%
sns.boxplot(df['loan_amount'])
plt.title('box plot of loan_amount')
plt.show()

# %% [markdown]
# insights:
#
# - most loan amounts are evenly distributed within the normal range.
# - The distribution of loan_amount is positive
# - The loan_amount data does not contain significant outliers.
# - the distribution is fairly balanced
# - the loan amount range from low to high values.
# - the loan amounts are well distributed, with applicatants requesting different loan amounts.

# %% [markdown]
# ## 	Distribution Plot

# %%
sns.histplot(df['cibil_score'], kde=True)
plt.title('cibil_score')
plt.show()

# %% [markdown]
# insights:
#
# - The Cibil score range from 300 to 900
# - the score are spread across all range
# - the data is well distributed
# - there are both low and high score applicants in the dataset
# - cibil score is an important feature for predicting loan approval

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# ## Scatter Plot

# %%
sns.scatterplot(x='income_annum',
                y='loan_amount',
                hue='loan_status',
                data=df)
plt.title('income_annum')
plt.show()

# %% [markdown]
# insights:
#
# - the loan amount increases as annual income increases
# - applicants with higher income generally receive higher loan amount
# - both approved  and rejected loans are present across different income levels
# - approved loans are more frequent than rejected loans
# - loan approval depends on income as well as other factors like assetc and Cibil score

# %% [markdown]
# ## Bar Plot

# %%
sns.barplot(x='education',
            y='income_annum',
            data=df)
plt.title('education')
plt.show()

# %% [markdown]
# insights:
#
# - graduated and not graduated have similar average income
# - no more difference is absevered between the two groups
# - here education is not enough to explain income differences
# - other factors may impact applicants income

# %% [markdown]
# ## Box Plot

# %%
sns.boxplot(x='loan_status',
            y='cibil_score',
            data=df)
plt.title('loan status')
plt.show()

# %% [markdown]
# insights:
#
# - applicants with approved loans have higher CIBIL score than applicants with rejected loans
# - most rejected applicants have lower cibil score
# - there are a few outliers in both approval and rejected categories
# - higher CIBIL score increases the chances of loan approval.

# %% [markdown]
# ## Violin Plot

# %%
sns.violinplot(x='loan_status',
               y='income_annum',
               data=df)
plt.title('income_annum')
plt.show()

# %% [markdown]
# insights:
#
# - The annual income of both Approved and Rejected applicants is spread over a wide range.
# - The median income is almost the same for both groups.
# - The income distribution looks similar for both loan statuses.
# - Median income is nearly the same for both groups.
# - Income alone does not determine loan approval.
# - Other factors like CIBIL score and assets also affect loan approval.

# %% [markdown]
# # Multivariate Analysis

# %% [markdown]
# ## Pair Plot

# %%
sns.pairplot(
    df[[
        'income_annum',
        'loan_amount',
        'cibil_score',
        'loan_status',        
    ]],
    hue='loan_status'
    
)
plt.show()

# %% [markdown]
# ## Heatmap

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(numeric_only=True),
            annot=True,
            cmap='coolwarm')
plt.title("Correlation Heatmap - Loan Approval Dataset")

plt.show()

# %% [markdown]
# insights:
#
# - income_annum and loan_amount have a strong positive correlation (0.93).
# - Applicants with higher income generally receive higher loan amounts.
# - income_annum and luxury_assets_value have a strong positive correlation (0.93).
# - Higher-income applicants tend to own more luxury assets.
# - income_annum and bank_asset_value have a strong positive correlation (0.85).
# - Higher-income applicants usually have higher bank assets.
# - loan_amount and luxury_assets_value have a strong positive correlation (0.86).
# - Applicants with more luxury assets tend to receive larger loans.
# - loan_amount and bank_asset_value have a strong positive correlation (0.79).
# - Applicants with higher bank assets tend to get higher loan amounts.
# - residential_assets_value and commercial_assets_value have a moderate positive correlation (0.41)
# - cibil_score has very weak correlation with the other numerical features.
# - This means the CIBIL score is relatively independent of income, loan amount, and assets.
# - loan_id has no meaningful correlation with any feature.
# - It is only an identifier and should not affect the prediction.

# %% [markdown]
# ## Correlation Matrix

# %%
df.corr(numeric_only=True)   # CIBIL score and income show positive relationships with loan approval-related features.
# Out:
#                            loan_id  no_of_dependents  income_annum  \
# loan_id                   1.000000          0.005326      0.012592
# no_of_dependents          0.005326          1.000000      0.007266
# income_annum              0.012592          0.007266      1.000000
# loan_amount               0.008170         -0.003366      0.927470
# loan_term_years           0.009809         -0.020111      0.011488
# cibil_score               0.016323         -0.009998     -0.023034
# residential_assets_value  0.020936          0.007376      0.636841
# commercial_assets_value   0.018595         -0.001531      0.640328
# luxury_assets_value      -0.000862          0.002817      0.929145
# bank_balance              0.010765          0.011163      0.851093
#
#                           loan_amount  loan_term_years  cibil_score  \
# loan_id                      0.008170         0.009809     0.016323
# no_of_dependents            -0.003366        -0.020111    -0.009998
# income_annum                 0.927470         0.011488    -0.023034
# loan_amount                  1.000000         0.008437    -0.017035
# loan_term_years              0.008437         1.000000     0.007810
# cibil_score                 -0.017035         0.007810     1.000000
# residential_assets_value     0.594596         0.008016    -0.019947
# commercial_assets_value      0.603188        -0.005478    -0.003769
# luxury_assets_value          0.860914         0.012490    -0.028618
# bank_balance                 0.788122         0.017177    -0.015478
#
#                           residential_assets_value  commercial_assets_value  \
# loan_id                                   0.020936                 0.018595
# no_of_dependents                          0.007376                -0.001531
# income_annum                              0.636841                 0.640328
# loan_amount                               0.594596                 0.603188
# loan_term_years                           0.008016                -0.005478
# cibil_score                              -0.019947                -0.003769
# residential_assets_value                  1.000000                 0.414786
# commercial_assets_value                   0.414786                 1.000000
# luxury_assets_value                       0.590932                 0.591128
# bank_balance                              0.527418                 0.548576
#
#                           luxury_assets_value  bank_balance
# loan_id                             -0.000862      0.010765
# no_of_dependents                     0.002817      0.011163
# income_annum                         0.929145      0.851093
# loan_amount                          0.860914      0.788122
# loan_term_years                      0.012490      0.017177
# cibil_score                         -0.028618     -0.015478
# residential_assets_value             0.590932      0.527418
# commercial_assets_value              0.591128      0.548576
# luxury_assets_value                  1.000000      0.788517
# bank_balance                         0.788517      1.000000

# %% [markdown]
# # Phase 6: Feature Engineering (10 Marks)

# %% [markdown]
# ## Feature Engineering is the process of preoaring raw data so that machine learning model can learn effectively

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.tree import plot_tree
from sklearn.preprocessing import LabelEncoder

# %%
df.columns
# Out:
# Index(['loan_id', 'no_of_dependents', 'education', 'self_employed',
#        'income_annum', 'loan_amount', 'loan_term_years', 'cibil_score',
#        'residential_assets_value', 'commercial_assets_value',
#        'luxury_assets_value', 'bank_balance', 'loan_status'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
df['education'] = le.fit_transform(df['education'])  
df['loan_status'] = le.fit_transform(df['loan_status'])

# %%
df['loan_status'].head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    1
# Name: loan_status, dtype: int64

# %% [markdown]
# ## Feature Selection

# %%
from sklearn. preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
df.head(3)
# Out:
#    loan_id  no_of_dependents  education self_employed  income_annum  \
# 0        1                 2          0            No       9600000
# 1        2                 0          1           Yes       4100000
# 2        3                 3          0            No       9100000
#
#    loan_amount  loan_term_years  cibil_score  residential_assets_value  \
# 0     29900000               12          778                   2400000
# 1     12200000                8          417                   2700000
# 2     29700000               20          506                   7100000
#
#    commercial_assets_value  luxury_assets_value  bank_balance  loan_status
# 0                 17600000             22700000       8000000            0
# 1                  2200000              8800000       3300000            1
# 2                  4500000             33300000      12800000            1

# %%
df.columns
# Out:
# Index(['loan_id', 'no_of_dependents', 'education', 'self_employed',
#        'income_annum', 'loan_amount', 'loan_term_years', 'cibil_score',
#        'residential_assets_value', 'commercial_assets_value',
#        'luxury_assets_value', 'bank_balance', 'loan_status'],
#       dtype='object')

# %%
scale_columns=[
    'income_annum', 
    'loan_amount',
    'cibil_score',
    'residential_assets_value', 
    'commercial_assets_value',
    'luxury_assets_value',
    'bank_balance'
]

df[scale_columns]=scaler.fit_transform(df[scale_columns])

# %% [markdown]
# ## Handling Skewness

# %%
print(df.skew(numeric_only=True))
# Out:
# loan_id                     0.000000
# no_of_dependents           -0.017971
# education                   0.008905
# income_annum               -0.012814
# loan_amount                 0.308724
# loan_term_years             0.036359
# cibil_score                -0.009039
# residential_assets_value    0.978451
# commercial_assets_value     0.957791
# luxury_assets_value         0.322208
# bank_balance                0.560725
# loan_status                 0.504087
# dtype: float64

# %% [markdown]
# ## train_test_split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
print(df.dtypes)
# Out:
# loan_id                      int64
# no_of_dependents             int64
# education                    int64
# self_employed               object
# income_annum                 int64
# loan_amount                  int64
# loan_term_years              int64
# cibil_score                  int64
# residential_assets_value     int64
# commercial_assets_value      int64
# luxury_assets_value          int64
# bank_balance                 int64
# loan_status                  int64
# dtype: object

# %% [markdown]
# ##  Model Building

# %% [markdown]
# ## LogisticRegression

# %% [markdown]
# train multiple classification algorithms, comapare their performance and identify
#
# the best model for loan Approval prediction

# %%
from sklearn.linear_model import LogisticRegression

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
lr=LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred_lr=lr.predict(x_test)

# %%
accuracy_score(y_test,y_pred_lr)
# Out:
# 0.6323185011709602

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt=DecisionTreeClassifier(max_depth=5,random_state=42)

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, random_state=42)

# %%
y_pred_dt=dt.predict(x_test)

# %%
accuracy_score(y_test,y_pred_dt)
# Out:
# 0.9695550351288056

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf=RandomForestClassifier(
    n_estimators=100,
    random_state=42,
    
)
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred_rf=rf.predict(x_test)

# %%
accuracy_score(y_test,y_pred_rf)
# Out:
# 0.9754098360655737

# %% [markdown]
# ## K-Nearest Neighbors (KNN)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn=KNeighborsClassifier(n_neighbors=3)
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred_knn=knn.predict(x_test)

# %%
accuracy_score(y_test,y_pred_knn)
# Out:
# 0.5562060889929742

# %% [markdown]
# ## XGBoost

# %%
from xgboost import XGBClassifier

# %%
xgb = XGBClassifier()
xgb.fit(x_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=True, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
y_pred_xgb=xgb.predict(x_test)

# %%
accuracy_score(y_test,y_pred_xgb)
# Out:
# 0.977751756440281

# %% [markdown]
# # SVC

# %%
from sklearn.svm import SVC

# %%
svc = SVC(kernel='rbf')
svc.fit(x_train, y_train)
# Out:
# SVC()

# %%
y_pred_svc=svc.predict(x_test)

# %%
accuracy_score(y_test,y_pred_svc)
# Out:
# 0.6276346604215457

# %% [markdown]
# # Ada boost

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
ada = AdaBoostClassifier(n_estimators=100,random_state=42)
ada.fit(x_train, y_train)
# Out:
# AdaBoostClassifier(n_estimators=100, random_state=42)

# %%
y_pred_ada=ada.predict(x_test)

# %%
accuracy_score(y_test,y_pred_ada)
# Out:
# 0.9648711943793911

# %% [markdown]
# ### Compare All Models

# %%
results=pd.DataFrame({
    'models':[
        'logistic regression',
        'decision tree',
        'random forest',
        'KNN',
        'SVM',
        'adamboost',
        'XGBboost'
    ],
    'Accuracy':[
        accuracy_score(y_test,y_pred_lr),
        accuracy_score(y_test,y_pred_dt),
        accuracy_score(y_test,y_pred_rf),
        accuracy_score(y_test,y_pred_knn),
        accuracy_score(y_test,y_pred_svc),
        accuracy_score(y_test,y_pred_ada),
        accuracy_score(y_test,y_pred_xgb),
        
    ]
})

result=results.sort_values(by='Accuracy',ascending=False)

# %%
results
# Out:
#                 models  Accuracy
# 0  logistic regression  0.632319
# 1        decision tree  0.969555
# 2        random forest  0.975410
# 3                  KNN  0.556206
# 4                  SVM  0.627635
# 5            adamboost  0.964871
# 6             XGBboost  0.977752

# %% [markdown]
# # Phase 9: Model Evaluation (10 Marks)
# ## Classification Metrics

# %%
from sklearn.metrics import classification_report

# %%
y_pred = model.predict(x_test)
print('Accuracy:',accuracy_score(y_test,y_pred))
print('Confusion matrix:',confusion_matrix(y_test,y_pred))
# Out:
# Accuracy: 0.9648711943793911
# Confusion matrix: [[521  15]
#  [ 15 303]]

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97       536
#            1       0.95      0.95      0.95       318
#
#     accuracy                           0.96       854
#    macro avg       0.96      0.96      0.96       854
# weighted avg       0.96      0.96      0.96       854

# %% [markdown]
# ##  Regression Metrics

# %% [markdown]
# ## MAE

# %%
mae=mean_absolute_error(y_test,y_pred)
mae
# Out:
# 0.0351288056206089

# %% [markdown]
# ## MSE

# %%
mse=mean_squared_error(y_test,y_pred)
mse
# Out:
# 0.0351288056206089

# %% [markdown]
# ## RMSE

# %%
rmse=np.sqrt(mse)
rmse
# Out:
# np.float64(0.18742680069992365)

# %% [markdown]
# ## R² Score

# %%
r2=r2_score(y_test,y_pred)  
r2
# Out:
# 0.8496902281047592

# %% [markdown]
# # Phase 10: Hyperparameter Tuning (5 Marks)

# %% [markdown]
# ## GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV
from xgboost import XGBClassifier

# %%
param_grid={
    'max_depth':[5,10,15],
    'n_estimators':[100,300,500],
    'learning_rate':[0.01,0.1,0.2]

}

grid=GridSearchCV(
    xgb,
    param_grid,
    cv=5,
    scoring='accuracy'
)
grid.fit(x_train,y_train)
print(grid.best_params_)
# Out:
# {'learning_rate': 0.01, 'max_depth': 15, 'n_estimators': 300}

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'learning_rate': 0.01, 'max_depth': 15, 'n_estimators': 300}
# 0.9821376281112737

# %% [markdown]
# ## RandomizedSearchCV

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier

# %%
param_grid={
'n_estimators':[100,200,300],
'max_depth':[5,10,15],
'criterion':['gini','entropy']
}
grid=GridSearchCV(
    RandomForestClassifier(random_state=42),
param_grid,
cv=5,
    scoring='accuracy'
)

# %%
grid.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [5, 10, 15],
#                          'n_estimators': [100, 200, 300]},
#              scoring='accuracy')

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'criterion': 'entropy', 'max_depth': 15, 'n_estimators': 100}
# 0.9777452415812592

# %% [markdown]
# # feature importance

# %%
Importance_xgb=pd.DataFrame({
    'features':x.columns,
    'importance':xgb.feature_importances_
})

Importance=Importance_xgb.sort_values(by='importance',ascending=False)
Importance
# Out:
#                     features  importance
# 6                cibil_score    0.699128
# 5            loan_term_years    0.190473
# 3               income_annum    0.023845
# 4                loan_amount    0.022706
# 7   residential_assets_value    0.011590
# 9        luxury_assets_value    0.010773
# 1           no_of_dependents    0.008229
# 8    commercial_assets_value    0.007641
# 0                    loan_id    0.007477
# 10              bank_balance    0.006720
# 2                  education    0.006050
# 11        self_employed_ Yes    0.005367

# %% [markdown]
# # Final Insights and Recommendations

# %% [markdown]
# - CIBIL Score: Most important feature (69.91%); prioritize credit score when evaluating loan applications.
# - Loan Term: Second most important feature (19.05%); consider repayment period carefully during approval.
# - Income: Has a moderate-low influence (2.38%); verify income to assess repayment capacity.
# - Loan Amount: Has a low influence (2.27%); compare the requested amount with repayment ability.
# - Residential Assets: Has low influence (1.16%); use residential assets as supporting financial information.
# - Luxury Assets: Has low influence (1.08%); consider luxury assets as additional financial information.
# - No. of Dependents: Has very low influence (0.82%); consider dependents as a secondary financial factor.
# - Commercial Assets: Has very low influence (0.76%); use commercial assets as supporting financial information.
# - Loan ID: Has little meaningful influence (0.75%); remove it because it is an identifier, not a meaningful loan feature.
# - Bank Balance: Has very low influence (0.67%); use bank balance as supporting evidence of financial stability.
# - Education: Has very low influence (0.61%); consider education as a secondary factor.
# - Self-Employed: Has the lowest influence (0.54%); treat employment status as a supporting factor.

# %%
x
# Out:
#       loan_id  no_of_dependents  education  income_annum  loan_amount  \
# 0           1                 2          0       9600000     29900000
# 1           2                 0          1       4100000     12200000
# 2           3                 3          0       9100000     29700000
# 3           4                 3          0       8200000     30700000
# 4           5                 5          1       9800000     24200000
# ...       ...               ...        ...           ...          ...
# 4264     4265                 5          0       1000000      2300000
# 4265     4266                 0          1       3300000     11300000
# 4266     4267                 2          1       6500000     23900000
# 4267     4268                 1          1       4100000     12800000
# 4268     4269                 1          0       9200000     29700000
#
#       loan_term_years  cibil_score  residential_assets_value  \
# 0                  12          778                   2400000
# 1                   8          417                   2700000
# 2                  20          506                   7100000
# 3                   8          467                  18200000
# 4                  20          382                  12400000
# ...               ...          ...                       ...
# 4264               12          317                   2800000
# 4265               20          559                   4200000
# 4266               18          457                   1200000
# 4267                8          780                   8200000
# 4268               10          607                  17800000
#
#       commercial_assets_value  luxury_assets_value  bank_balance  \
# 0                    17600000             22700000       8000000
# 1                     2200000              8800000       3300000
# 2                     4500000             33300000      12800000
# 3                     3300000             23300000       7900000
# 4                     8200000             29400000       5000000
# ...                       ...                  ...           ...
# 4264                   500000              3300000        800000
# 4265                  2900000             11000000       1900000
# 4266                 12400000             18100000       7300000
# 4267                   700000             14100000       5800000
# 4268                 11800000             35700000      12000000
#
#       self_employed_ Yes
# 0                  False
# 1                   True
# 2                  False
# 3                  False
# 4                   True
# ...                  ...
# 4264                True
# 4265                True
# 4266               False
# 4267               False
# 4268               False
#
# [4269 rows x 12 columns]
